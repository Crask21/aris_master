# %%
import torch
from torch import nn

embedding = nn.Embedding(10, 8)

# %%
input = torch.LongTensor([1])  # Example input indices
with torch.no_grad():
    output = embedding(input)
print(output)  # Output the embeddings for the input indices
# Out:
# tensor([[ 0.2021, -0.4282,  0.7290,  0.1590,  0.3434,  2.1865, -2.6471,  2.4590]])
